# %%
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df=pd.read_html(url)[0]
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# now we need to clean out data from not assigned value in column 'Borough'

# %%
index=df[df['Borough']=='Not assigned'].index
df.drop(index , inplace=True)
df.reset_index(drop=True)
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park / Harbourfront
# 3                    Lawrence Manor / Lawrence Heights
# 4         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway / Montgomery Road / Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# now let's look if theres in 'Neighborhood' rows with NaN  or Not assigned value

# %%
df[df['Neighborhood']=='NaN']
# Out:
# Empty DataFrame
# Columns: [Postal code, Borough, Neighborhood]
# Index: []

# %%
df[df['Neighborhood']==' Not assigned']
# Out:
# Empty DataFrame
# Columns: [Postal code, Borough, Neighborhood]
# Index: []

# %% [markdown]
# as we  see our data is clean
# now we need to replace (/) in Neighborhood column with (,)

# %%
import numpy as np
na=[]
x='/'
y=','

for dat in df['Neighborhood']:
    m=dat.replace(x,y)
    na.append(m)
    
new_n=np.array(na)
df.Neighborhood=new_n

# %%
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 5         M6A        North York             Lawrence Manor , Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4         Queen's Park , Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# Now we gonna use file csv witch contain latitude and longitude for each postal code

# %%
geo=pd.read_csv('Geospatial_Coordinates.csv')
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo.shape
# Out:
# (103, 3)

# %% [markdown]
# as we see thy have the same nombre of rows
# witch make our work easy  just we ganna ordered the both data frame and concatenate  it (we know that  from the instruction of the assignement the geo contain latitude and longitude  for every postal code in our data  )

# %%
geo.sort_values(by='Postal Code',inplace=True)
df.sort_values(by='Postal code',inplace=True)
geo.reset_index(drop=True,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df
# Out:
#     Postal code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood
# 0                                      Malvern , Rouge
# 1             Rouge Hill , Port Union , Highland Creek
# 2                  Guildwood , Morningside , West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village , St. Phillips , Martin Grov...
# ...

# %%
frames = [df, geo]
result = pd.concat(frames,axis=1)

# %%
result
# Out:
#     Postal code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 0                                      Malvern , Rouge         M1B  43.806686
# 1             Rouge Hill , Port Union , Highland Creek         M1C  43.784535
# 2                  Guildwood , Morningside , West Hill         M1E  43.763573
# 3                                               Woburn         M1G  43.770992
# 4                                            Cedarbrae         M1H  43.773136
# ..                                                 ...         ...        ...
# ...

# %%
result=result[['Postal code','Borough','Neighborhood','Latitude','Longitude']]
result.head()
